# %%
from microstructpy.markets.continous import ContinousOrderBookMarket
from microstructpy.traders.noise import NoiseTrader
from microstructpy.traders.market_maker import MarketMaker
from microstructpy.traders.informed import InformedTrader
from microstructpy.visualization.summary import participant_comparison
from microstructpy.metrics.trader_metrics import get_profit_history

import time
import matplotlib.pyplot as plt
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from microstructpy.markets.market import ContinousOrderBookMarket
#       2 from microstructpy.traders.trader import LiquidityTrader, ConstantPriceDealer, InformedTrader
#       3 from microstructpy.visualization.viz import price_path, participant_comparison
#
# ModuleNotFoundError: No module named 'microstructpy.markets.market'

# %%
market = ContinousOrderBookMarket()

# %%
liq_trader = NoiseTrader(1, market, 1, 1)
dealer = MarketMaker(2, market, 10, 2, 100)
inf_trader = InformedTrader(3, market, 100, 14)

# %%
market.run(1000)

# %%
participant_comparison(market.participants)
