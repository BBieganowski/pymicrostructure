# %%
from microstructpy.markets.continous import ContinousOrderBookMarket
from microstructpy.traders.noise import NoiseTrader
from microstructpy.traders.market_maker import MarketMaker
from microstructpy.traders.informed import InformedTrader, TWAPTrader
from microstructpy.visualization.summary import participant_comparison
from microstructpy.metrics.trader_metrics import *

import time
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
market = ContinousOrderBookMarket()

# %%
liq_trader = NoiseTrader(1, market, 1, 1)
dealer = MarketMaker(2, market, 10, 2, 100)
inf_trader = TWAPTrader(3, market, 100, 14)

# %%
market.run(1000)

# %%
participant_comparison(market.participants)

# %%
participants_report(market.participants)
# Out:
# c:\Users\Bartek\Desktop\microstructure\microstructpy\metrics\trader_metrics.py:82: RuntimeWarning: invalid value encountered in scalar divide
#   return profit_per_state(trader) / std_profit_per_state(trader)
#                       MarketMaker_2  TWAPTrader_3  NoiseTrader_1
# final_profit                    0.0           0.0            0.0
# final_position                  0.0           0.0            0.0
# profit_per_state                0.0           0.0            0.0
# std_profit_per_state            0.0           0.0            0.0
# information_ratio               NaN           NaN            NaN
# total_trades                    0.0           0.0            0.0
# volume_traded                   0.0           0.0            0.0
# profit_per_volume               0.0           0.0            0.0
# average_trade_size              0.0           0.0            0.0
# fill_rate                       0.0           0.0            0.0
# time_in_market                  0.0           0.0            0.0
# mean_position                   0.0           0.0            0.0
# mean_abs_position               0.0           0.0            0.0
# volume_as_agressor              0.0           0.0            0.0
# volume_as_passive               0.0           0.0            0.0
# agressor_ratio                  0.0           0.0            0.0
